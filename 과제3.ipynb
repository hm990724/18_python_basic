# %%
##문제3

# 문제 1. 리스트 내장 함수

아래 리스트에 대해 내장 함수를 사용하여 다음을 구하시오.

scores = [85, 92, 78, 90, 88, 76, 95, 89]

1) 리스트의 길이 (len)
print(len(scores))
2) 최댓값 (max)
print(max(scores))
3) 최솟값 (min)
print(min(scores))
4) 총합 (sum)
print(sum(scores))
5) 평균 (sum과 len 활용)
print(sum(scores)/len(scores))
6) 정렬된 새 리스트 반환 (sorted)
print(sorted(scores))
7) 내림차순 정렬 (sorted, reverse=True)
print(sorted(scores, reverse=True))



# 문제 2. 리스트와 문자열

다음 작업을 수행하시오.

1) 문자열 "Hello World"를 문자 리스트로 변환 (list)
2) 문자열 "a,b,c,d,e"를 쉼표로 분리하여 리스트로 변환 (split)
3) 리스트 ["Python", "is", "fun"]을 공백으로 연결하여 문자열로 변환 (join)

a = "Hello World"
b = "a,b,c,d,e"
c = ["Python", "is", "fun"]

print(list(a))

print(b.split(","))

print(" ".join(c))






# 문제 3. 요소 추가 메서드

빈 리스트에서 시작하여 다음 작업을 순서대로 수행하시오.

1) append()로 10, 20, 30을 차례로 추가하시오.
2) insert()로 인덱스 1에 15를 삽입하시오.
3) insert()로 인덱스 0에 5를 삽입하시오.
4) extend()로 [40, 50]을 추가하시오.
5) 각 단계마다 리스트를 출력하시오.

a = []

a.append(10)
a.append(20)
a.append(30)
print(a)

a.insert(1, 15)
print(a)

a.insert(0, 5)
print(a)

a.extend([40, 50])
print(a)




# 문제 4. 요소 제거 메서드

아래 리스트에서 다음 작업을 수행하시오.

items = ["a", "b", "c", "b", "d", "b", "e"]

1) remove()로 첫 번째 "b"를 제거하시오.
items.remove("b")
print(items)

2) pop()으로 마지막 요소를 제거하고, 제거된 값을 출력하시오.
items.pop()
print(items)

3) pop(0)으로 첫 번째 요소를 제거하시오.
items.pop(0)
print(items)

4) clear()로 모든 요소를 제거하시오.
items.clear()
print(items)

5) 각 단계마다 리스트를 출력하시오.




# 문제 5. 검색 및 카운트 메서드

아래 리스트에 대해 다음을 수행하시오.

data = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]

1) index()로 처음 나오는 5의 인덱스를 찾으시오.
print(data.index(4))

2) count()로 5가 몇 번 나오는지 세시오.
print(data.count((5)))

3) count()로 1이 몇 번 나오는지 세시오.
print(data.count((1)))




# 문제 6. 정렬 메서드

다음 작업을 수행하시오.

numbers = [64, 34, 25, 12, 22, 11, 90]
words = ["banana", "Apple", "cherry", "date"]

1) numbers를 sort()로 오름차순 정렬하시오.
numbers.sort()
print(numbers)

2) numbers를 sort(reverse=True)로 내림차순 정렬하시오.
numbers.sort(reverse=True)
print(numbers)

3) words를 알파벳순으로 정렬하시오.
words.sort()
print(words)

4) reverse()로 리스트 순서를 뒤집으시오.
words.reverse()
print(words)



# 문제 7. 튜플 생성과 기본 구조

다음 조건을 만족하는 프로그램을 작성하시오.

1) 정수 1, 2, 3, 4, 5를 담은 튜플을 생성하시오.
a = (1, 2, 3, 4, 5)
print(a)

2) 문자열 "red", "green", "blue"를 담은 튜플을 생성하시오.
b = ("red", "green", "blue")
print(b)

3) 요소가 하나뿐인 튜플을 올바르게 생성하시오. 
a = (1, )
print(a)

4) 빈 튜플을 두 가지 방법((), tuple())으로 생성하시오.
a = ()
b = tuple()
print(a, b)

5) 괄호 없이 튜플을 생성하시오. 
a = 1, 2, 3
print(a)

6) 각 튜플의 길이(len)와 자료형(type)을 출력하시오.
print(len(a),type(a))
print(len(b),type(b))


# 문제 8. 튜플 생성과 기본 구조

다음 조건을 만족하는 프로그램을 작성하시오.

1) 정수 1, 2, 3, 4, 5를 담은 튜플을 생성하시오.
2) 문자열 "red", "green", "blue"를 담은 튜플을 생성하시오.
3) 요소가 하나뿐인 튜플을 올바르게 생성하시오. (주의: 쉼표 필요)
4) 빈 튜플을 두 가지 방법((), tuple())으로 생성하시오.
5) 괄호 없이 튜플을 생성하시오. (패킹)
6) 각 튜플의 길이(len)와 자료형(type)을 출력하시오.

##겹치는 문제 패스



# 문제 9. 튜플 인덱싱

아래 튜플이 주어졌을 때, 다음을 출력하시오.

colors = ("빨강", "주황", "노랑", "초록", "파랑", "남색", "보라")

1) 첫 번째 요소
print(colors[0])

2) 마지막 요소 (음수 인덱스 사용)
print(colors[-1])

3) 세 번째 요소
print(colors[2])

4) 뒤에서 세 번째 요소
print(colors[-3])

5) 인덱스 4에 해당하는 요소
print(colors[4])


# 문제 10. 딕셔너리 기본 개념
다음 질문에 답하시오.

1. 딕셔너리는 무엇으로 구성되어 있는가?
(Key - Value)

2. 딕셔너리와 리스트의 가장 큰 차이점은 무엇인가?
(리스트는 순서가 존재, 딕셔너리는 순서가 없되 고유한 키 값 사용)

3. 다음 중 딕셔너리의 Key로 사용할 수 없는 것은? (이유도 함께 설명)
   - a) 숫자 (1, 2, 3)
   - b) 문자열 ("name", "age")
   - c) 리스트 ([1, 2, 3])
   - d) 튜플 ((1, 2, 3))

(c - 리스트는 변경 가능하기에 딕셔너리는 Key 변경 불가)


# 문제 11. 코드 읽기
다음 코드의 실행하시오

student = {'name': '김철수', 'age': 20, 'major': '컴퓨터공학'}
print(student['name'])
print(student['age'])

결과 : 김철수 
        20



# 문제 12. 딕셔너리 생성 및 조작
다음 조건에 맞는 딕셔너리를 생성하고 조작하시오.


# 1. 다음 정보를 담는 딕셔너리를 만드시오
#    - 이름: 본인 이름
#    - 나이: 본인 나이
#    - 취미: 본인 취미 (리스트로 여러 개)
#    - 거주지: 본인 거주지
a = {
    '이름': '정현민',
    '나이': 28,
    '취미': ['게임', '영화'],
    '거주지': '구미'
}


# 2. 위 딕셔너리에 '전공' 항목을 추가하시오

a['전공'] = '컴공'

# 3. '취미' 항목에 새로운 취미를 추가하시오

a['취미'].append('놀기')

# 4. '나이' 항목의 값을 1 증가시키시오

a['나이'] += 1

# 5. 모든 key와 value를 출력하시오

print(a)

# 문제 13. 딕셔너리 함수 활용
다음 딕셔너리가 주어졌을 때, 각 요구사항을 수행하시오.


fruits = {
    'apple': 1000,
    'banana': 1500,
    'orange': 2000,
    'grape': 3000
}

# 1. 모든 과일 이름(key)을 리스트로 출력하시오

print(list(fruits.keys()))

# 2. 모든 가격(value)을 리스트로 출력하시오

print(list(fruits.values()))

# 3. 'banana'의 가격을 출력하시오

print(fruits['banana'])

# 4. 'melon'이 딕셔너리에 있는지 확인하시오

print('melon' in fruits)

# 5. 'grape'를 pop() 함수를 사용하여 삭제하고, 삭제된 값을 출력하시오

print(fruits.pop('grape'))



# 문제 14. 성적 관리 프로그램
학생들의 성적을 관리하는 프로그램을 작성하시오.

# 다음 학생들의 성적 정보를 딕셔너리로 저장하시오
# 학생1: 이름=김민수, 국어=85, 영어=90, 수학=78
# 학생2: 이름=이영희, 국어=92, 영어=88, 수학=95
# 학생3: 이름=박철수, 국어=78, 영어=85, 수학=82

student = {
    '김민수': {'국어': 85, '영어': 90, '수학': 78},
    '이영희': {'국어': 92, '영어': 88, '수학': 95},
    '박철수': {'국어': 78, '영어': 85, '수학': 82}
}

# 요구사항:
# 1. 각 학생의 총점과 평균을 계산하여 딕셔너리에 추가
# 2. 각 학생의 정보를 보기 좋게 출력

**출력 예시:**

=== 학생 성적 관리 ===
이름: 김민수
국어: 85점, 영어: 90점, 수학: 78점
총점: 253점, 평균: 84.33점
---
이름: 이영희
국어: 92점, 영어: 88점, 수학: 95점
총점: 275점, 평균: 91.67점
---
이름: 박철수
국어: 78점, 영어: 85점, 수학: 82점
총점: 245점, 평균: 81.67점
---

print("=== 학생 성적 관리 ===")

# 김민수
m_total = sum(student['김민수'].values())
m_avg = m_total / len(student['김민수'])
print("이름: 김민수")
print(f"국어: {student['김민수']['국어']}점, 영어: {student['김민수']['영어']}점, 수학: {student['김민수']['수학']}점")
print(f"총점: {m_total}점, 평균: {m_avg:.2f}점")
print("---")

# 이영희
l_total = sum(student['이영희'].values())
l_avg = l_total / len(student['이영희'])
print("이름: 이영희")
print(f"국어: {student['이영희']['국어']}점, 영어: {student['이영희']['영어']}점, 수학: {student['이영희']['수학']}점")
print(f"총점: {l_total}점, 평균: {l_avg:.2f}점")
print("---")

# 박철수
p_total = sum(student['박철수'].values())
p_avg = p_total / len(student['박철수'])
print("이름: 박철수")
print(f"국어: {student['박철수']['국어']}점, 영어: {student['박철수']['영어']}점, 수학: {student['박철수']['수학']}점")
print(f"총점: {p_total}점, 평균: {p_avg:.2f}점")
print("---")



# 문제 15. 단어 카운터
문자열에서 각 단어가 몇 번 등장하는지 세는 프로그램을 작성하시오.

text = "python is great python is fun python is powerful"

# 요구사항:
# 1. 문자열을 공백으로 분리하여 단어 리스트 만들기
# 2. 각 단어의 등장 횟수 세기
# 3. 결과를 출력



**출력 예시:**

python: 3번
is: 3번
great: 1번
fun: 1번
powerful: 1번

text.split()
print(f"python: {text.count('python')}번")
print(f"is: {text.count('is')}번")
print(f"great: {text.count('great')}번")
print(f"fun: {text.count('fun')}번")
print(f"powerful: {text.count('powerful')}번")




# 문제 16. 중첩 딕셔너리
다음과 같은 중첩 딕셔너리를 다루는 문제를 해결하시오.


school = {
    '1반': {
        '김철수': {'국어': 85, '영어': 90, '수학': 78},
        '이영희': {'국어': 92, '영어': 88, '수학': 95}
    },
    '2반': {
        '박민수': {'국어': 88, '영어': 85, '수학': 90},
        '최지영': {'국어': 95, '영어': 92, '수학': 88}
    }
}

# 요구사항:
# 1. '1반' 김철수의 수학 점수를 출력하시오
print(school['1반']['김철수']['수학'])
# 2. '2반' 박민수의 평균 점수를 계산하여 출력하시오
total = (sum([school['2반']['박민수']['영어']])+sum([school['2반']['박민수']['국어']])+sum([school['2반']['박민수']['수학']]))/3
print(total)


# 문제 17-1.
school = [
        {'이름': '김철수', '국어': 85, '영어': 90, '수학': 78},
        {'이름': '이영희', '국어': 92, '영어': 88, '수학': 95}, 
        {'이름': '박민수', '국어': 88, '영어': 85, '수학': 90},
        {'이름': '최지영', '국어': 95, '영어': 92, '수학': 88}
]
# 요구사항:
# 1. 최지영의 국어 점수를 출력하시오
print(school[3]['국어'])
# 2. 이영희의 평균 점수를 계산하여 출력하시오
total = (sum([school[1]['국어']])+ sum([school[1]['영어']])+sum([school[1]['수학']]))/3
print(total)



# 문제 18. 다음 코드의 실행 결과를 예상하시오.

# 1)
s1 = set("Hello")
print(s1)

결과 : {'H', 'e', 'l', 'o'}

# 2)
s2 = set([1, 2, 3, 2, 1, 3, 4])
print(s2)

결과 : {1, 2, 3, 4}

# 3)
s3 = {}
print(type(s3))

결과 : <class 'dict'>




# 문제 19. 두 반의 학생 명단 비교

A반과 B반 학생 명단이 있습니다.


a_class = {'김철수', '이영희', '박민수', '최지영', '홍길동'}
b_class = {'박민수', '최지영', '정수민', '강호동', '이영희'}

다음 질문에 답하시오:


# 1. 두 반 모두에 있는 학생 (교집합)
print(a_class & b_class)
# 2. 두 반을 합친 전체 학생 (합집합)
print(a_class | b_class)
# 3. A반에만 있는 학생 (차집합)
print(a_class - b_class)
# 4. B반에만 있는 학생 (차집합)
print(b_class - a_class)



# 문제 20. 집합 조작하기

fruits = {'apple', 'banana', 'orange'}


다음 작업을 수행하는 코드를 작성하시오:


# 1. 'grape'를 추가하시오
fruits.add('grape')
# 2. 'melon', 'kiwi', 'mango'를 한 번에 추가하시오
fruits.update(['melon', 'kiwi', 'mango'])
# 3. 'banana'를 제거하시오
fruits.remove('banana')
# 4. 집합에 'strawberry'가 있는지 확인하시오
print('strawberry' in fruits)
# 5. 모든 과일을 제거하고 빈 집합으로 만드시오
fruits.clear()
