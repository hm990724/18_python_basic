# %%
# if 문의 기본구조

if 조건문:
    수행할 문장1,
    수행할 문장2.
    ...

else:
    수행 문장1
    수행 문장2
# Out:
#   Cell In[1], line 4
#     수행할 문장1,
#         ^
# SyntaxError: invalid syntax

# %%
money = True

if money == True:
    print("택시")
print("타고")
    print("가라")
# Out:
#   Cell In[2], line 6
#     print("가라")
#     ^
# IndentationError: unexpected indent

# %%
money = True

if money == True:
    print("택시")
    print("타고")
        print("가라")
# Out:
#   Cell In[3], line 6
#     print("가라")
#     ^
# IndentationError: unexpected indent

# %%
money = 3000

if money >= 3000:
    print("택시 타라")
else:
    print("걸어가라")
# Out:
# 택시 타라

# %%
# 돈이 3000원 이상 있거나 카드가 있다면 택시타고 가고 아니면 걸어가라

money = 2000
card = True

if money >= 3000 or card == True:
        print("택시")
else:
    print("걸어")
# Out:
# 택시

# %%
# 만약에 주머니에 돈이 있으면 택시타고 아니면 걸어라

주머니 = ["paper", "cellphone", "money"]

if 'money' in 주머니:
    print("택시")

else:
    print("걸어")
# Out:
# 택시

# %%
# 다양한 조건을 판단하는 elif
# 주머니에 돈이 있으면
