# %%
a = True
b = False

# %%
type(a)
type(b)
# Out:
# bool

# %%
print(1 == 1)
print(1 != 1)
print(1 < 2)
print(1 > 2)
# Out:
# True
# False
# True
# False

# %%
bool(1 == 1)
print(bool("python"))
print(bool(""))
print(bool(10))
print(bool(0))
print(bool([1, 2, 3]))
print(bool([]))
# Out:
# True
# False
# True
# False
# True
